# %%
import pandas as pd
import numpy as np
import requests

# %%
df = pd.read_csv('/content/movies.csv')

# %%
df.shape
# Out:
# (9980, 4)

# %%
df.head()
# Out:
#    Unnamed: 0                     title  \
# 0           0  The Shawshank Redemption
# 1           1             The Godfather
# 2           2     The Godfather Part II
# 3           3          Schindler's List
# 4           4              12 Angry Men
#
#                                             overview  \
# 0  Imprisoned in the 1940s for the double murder ...
# 1  Spanning the years 1945 to 1955, a chronicle o...
# 2  In the continuing saga of the Corleone crime f...
# 3  The true story of how businessman Oskar Schind...
# 4  The defense and the prosecution have rested an...
#
#                         genres
# 0           ['Drama', 'Crime']
# 1           ['Drama', 'Crime']
# 2           ['Drama', 'Crime']
# 3  ['Drama', 'History', 'War']
# 4                    ['Drama']

# %% [markdown]
# # Removing Extra Column #

# %%
df.drop(['Unnamed: 0'],inplace = True,axis=1)

# %%
df.head()
# Out:
#                       title  \
# 0  The Shawshank Redemption
# 1             The Godfather
# 2     The Godfather Part II
# 3          Schindler's List
# 4              12 Angry Men
#
#                                             overview  \
# 0  Imprisoned in the 1940s for the double murder ...
# 1  Spanning the years 1945 to 1955, a chronicle o...
# 2  In the continuing saga of the Corleone crime f...
# 3  The true story of how businessman Oskar Schind...
# 4  The defense and the prosecution have rested an...
#
#                         genres
# 0           ['Drama', 'Crime']
# 1           ['Drama', 'Crime']
# 2           ['Drama', 'Crime']
# 3  ['Drama', 'History', 'War']
# 4                    ['Drama']

# %% [markdown]
# # Performing NLP Steps

# %% [markdown]
# ## Step 1 : Lower Casing

# %%
df['title'] = df['title'].str.lower()
df['overview'] = df['overview'].str.lower()
df['genres'] = df['genres'].str.lower()

# %%
df.sample(10)
# Out:
#                         title  \
# 9071  three steps over heaven
# 2476                    crash
# 5445    underworld: evolution
# 2786             santa sangre
# 693            train to busan
# 8664                       rv
# 5379                   damage
# 4504    in the valley of elah
# 8472     new york, i love you
# 3281                 creed ii
#
#                                                overview  \
# 9071            a bad boy and a socialite girl hook-up.
# 2476  in post-sept. 11 los angeles, tensions erupt w...
# 5445  as the war between the vampires and the lycans...
# 2786  a former circus artist escapes from a mental h...
# 693   when a zombie virus pushes korea into a state ...
# 8664  climbing aboard their mammoth recreational veh...
# 5379  the life of a respected british politician at ...
# 4504  a career officer and his wife work with a poli...
# 8472  new york, i love you delves into the intimate ...
# 3281  between personal obligations and training for ...
#
#                                                  genres
# 9071                               ['drama', 'romance']
# 2476                                          ['drama']
# 5445                  ['fantasy', 'action', 'thriller']
# 2786                    ['thriller', 'drama', 'horror']
# 693       ['horror', 'thriller', 'action', 'adventure']
# 8664           ['family', 'comedy', 'romance', 'drama']
# 5379                               ['drama', 'romance']
# 4504  ['history', 'drama', 'thriller', 'crime', 'mys...
# 8472                     ['comedy', 'drama', 'romance']
# 3281                                ['drama', 'action']

# %% [markdown]
# ## Step 2 : Check for Unnesecarry Data & Remove it ##

# %%
import re

# %%
df['overview'].str.contains(r"<.*?>", regex=True).sum()
# Out:
# 0

# %%
df['overview'].str.contains(r"http[s]?://", regex=True).sum()
# Out:
# 0

# %%
## There are No Html Tags or Any Url

# %% [markdown]
# ## Step 3 : Remove Punctuations ( ! , ? , \ )

# %%
df['title'] = df['title'].str.replace(r'[^\w\s]', '', regex=True)
df['overview'] = df['overview'].str.replace(r'[^\w\s]', '', regex=True)
df['genres'] = df['genres'].str.replace(r'[^\w\s]', '', regex=True)

# %%
df.head()  # Now our Data is cleaned from punctuations
# Out:
#                       title  \
# 0  the shawshank redemption
# 1             the godfather
# 2     the godfather part ii
# 3           schindlers list
# 4              12 angry men
#
#                                             overview             genres
# 0  imprisoned in the 1940s for the double murder ...        drama crime
# 1  spanning the years 1945 to 1955 a chronicle of...        drama crime
# 2  in the continuing saga of the corleone crime f...        drama crime
# 3  the true story of how businessman oskar schind...  drama history war
# 4  the defense and the prosecution have rested an...              drama

# %% [markdown]
# ## Step 4 : Spelling Correction

# %%
from spellchecker import SpellChecker

# %%
spell = SpellChecker()

# %%
def correct_sentence(text):
    if not isinstance(text, str):
        return text
    words = text.split()
    corrected = [spell.correction(w) if w in spell else w for w in words]
    return " ".join(corrected)

# %%
df['overview'] = df['overview'].apply(correct_sentence)

# %%
df.head()  # All the Spellings Are Now Corrected
# Out:
#                       title  \
# 0  the shawshank redemption
# 1             the godfather
# 2     the godfather part ii
# 3           schindlers list
# 4              12 angry men
#
#                                             overview             genres
# 0  imprisoned in the 1940s for the double murder ...        drama crime
# 1  spanning the years 1945 to 1955 a chronicle of...        drama crime
# 2  in the continuing saga of the corleone crime f...        drama crime
# 3  the true story of how businessman oskar schind...  drama history war
# 4  the defense and the prosecution have rested an...              drama

# %% [markdown]
# # Step 5 : Removing Stop Words ( a , and , of )

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))

# %%
def remove_stopwords(text):
    if not isinstance(text, str):
        return text
    words = text.split()
    filtered = [w for w in words if w.lower() not in stop_words]
    return " ".join(filtered)

# %%
df ['overview'] = df['overview'].apply(remove_stopwords)

# %%
df['overview']  # Now All the Stop Words Are Removed
# Out:
# 0       imprisoned 1940s double murder wife lover upst...
# 1       spanning years 1945 1955 chronicle fictional i...
# 2       continuing saga corleone crime family young vi...
# 3       true story businessman oskar schindler saved t...
# 4       defense prosecution rested jury filing jury ro...
#                               ...
# 9975    small midwestern town prepares annual christma...
# 9976    one thousand years cataclysmic events forced h...
# 9977    ongoing war canine feline species put hold joi...
# 9978    cia agent interned failing kill international ...
# 9979    team space marines known rapid response tactic...
# Name: overview, Length: 9980, dtype: object

# %% [markdown]
# ## Step 6 : Tokenization

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
def tokenize_text(text):
    if not isinstance(text, str):  # handle NaN
        return []
    return word_tokenize(text)

# %%
df['overview'] = df['overview'].apply(tokenize_text)
df['genres'] = df['genres'].apply(tokenize_text)

# %%
df.sample(5)
# Out:
#                   title                                           overview  \
# 7662       the stranger  [two, strangers, strike, conversation, long, j...
# 3285  a fantastic woman  [marinas, life, thrown, turmoil, following, de...
# 1696      irma la douce  [naive, policeman, falls, love, prostitute, do...
# 764           manhattan  [manhattan, explores, life, middleaged, televi...
# 2964      sapphire blue  [gwen, discovered, shes, final, member, secret...
#
#                          genres
# 7662   [thriller, crime, drama]
# 3285                    [drama]
# 1696          [romance, comedy]
# 764    [comedy, drama, romance]
# 2964  [fantasy, romance, drama]

# %% [markdown]
# ## Step 7 : Stemming

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
def lemmatize_tokens(tokens):
    return [lemmatizer.lemmatize(w) for w in tokens]

# %%
df['overview'] = df['overview'].apply(lemmatize_tokens)

# %%
df['genres'] = df['genres'].apply(lemmatize_tokens)

# %%
df.head()
# Out:
#                       title  \
# 0  the shawshank redemption
# 1             the godfather
# 2     the godfather part ii
# 3           schindlers list
# 4              12 angry men
#
#                                             overview                 genres
# 0  [imprisoned, 1940s, double, murder, wife, love...         [drama, crime]
# 1  [spanning, year, 1945, 1955, chronicle, fictio...         [drama, crime]
# 2  [continuing, saga, corleone, crime, family, yo...         [drama, crime]
# 3  [true, story, businessman, oskar, schindler, s...  [drama, history, war]
# 4  [defense, prosecution, rested, jury, filing, j...                [drama]
