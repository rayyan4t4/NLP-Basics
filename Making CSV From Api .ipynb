# %% [markdown]
# <a href="https://colab.research.google.com/github/rayyan4t4/NLP-Basics/blob/main/Making%20CSV%20From%20Api%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 500):
    response = requests.get(
        f'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}'
    )
    temp = pd.DataFrame(response.json()['results'])[['title', 'overview', 'genre_ids']]
    df = pd.concat([df, temp], ignore_index=True)

# %%
df.head()
# Out:
#                       title  \
# 0  The Shawshank Redemption
# 1             The Godfather
# 2     The Godfather Part II
# 3          Schindler's List
# 4              12 Angry Men
#
#                                             overview        genre_ids
# 0  Imprisoned in the 1940s for the double murder ...         [18, 80]
# 1  Spanning the years 1945 to 1955, a chronicle o...         [18, 80]
# 2  In the continuing saga of the Corleone crime f...         [18, 80]
# 3  The true story of how businessman Oskar Schind...  [18, 36, 10752]
# 4  The defense and the prosecution have rested an...             [18]

# %%
df.shape
# Out:
# (9980, 3)

# %%
# another api for genre ids

# %%
genre_response = requests.get('https://api.themoviedb.org/3/genre/movie/list?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US').json()


genre_map = {g['id']: g['name'] for g in genre_response['genres']}

# %%
df['genres'] = df['genre_ids'].apply(lambda ids: [genre_map.get(i, "Unknown") for i in ids])

# %%
df.head()
# Out:
#                       title  \
# 0  The Shawshank Redemption
# 1             The Godfather
# 2     The Godfather Part II
# 3          Schindler's List
# 4              12 Angry Men
#
#                                             overview        genre_ids  \
# 0  Imprisoned in the 1940s for the double murder ...         [18, 80]
# 1  Spanning the years 1945 to 1955, a chronicle o...         [18, 80]
# 2  In the continuing saga of the Corleone crime f...         [18, 80]
# 3  The true story of how businessman Oskar Schind...  [18, 36, 10752]
# 4  The defense and the prosecution have rested an...             [18]
#
#                   genres
# 0         [Drama, Crime]
# 1         [Drama, Crime]
# 2         [Drama, Crime]
# 3  [Drama, History, War]
# 4                [Drama]

# %%
df.drop(columns=['genre_ids'], inplace=True)

# %%
df
# Out:
#                           title  \
# 0      The Shawshank Redemption
# 1                 The Godfather
# 2         The Godfather Part II
# 3              Schindler's List
# 4                  12 Angry Men
# ...                         ...
# 9975             A Walk in Time
# 9976             Vive la France
# 9977  The Cosmos on the Commode
# 9978                Rock'n Roll
# 9979                 Get Carter
#
#                                                overview  \
# 0     Imprisoned in the 1940s for the double murder ...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9975  While visiting Universal Studios in Hollywood ...
# 9976  Muzafar and Feruz are two easy going shepherds...
# 9977  Four comedic episodes framed within the story ...
# ...

# %%
df.to_csv('movies.csv')
